# %%
from newsapi import NewsApiClient

# %%
newsapi = NewsApiClient(api_key='dcd79b6f75a1480293c0b22d91402002')

# %%
nyt_articles = newsapi.get_everything(page_size=100,#q='bitcoin',
                                      #sources='bbc-news,new-york-times',
                                      domains='www.nytimes.com',
                                      from_param='2018-01-01',
                                      to='2018-07-30',
                                      language='en',
                                      sort_by='relevancy'
                                      
                                      )

# %%
len(nyt_articles['articles'])
# Out:
# 100

# %%
nyt_articles['articles']
# Out:
# []

# %%
#nyt_articles

# %%
all_articles = newsapi.get_everything(q='bitcoin',
                                      sources='breitbart-news',
                                      #domains='nytimes.com',
                                      from_param='2018-01-01',
                                      to='2018-01-30',
                                      language='en',
                                      sort_by='relevancy',
                                      page=1)

# %%
all_articles
# Out:
# {'articles': [{'author': 'Tom Ciccotta',
#    'description': 'Vanguard CEO Tim Buckley says that the investment advising firm will never create a Bitcoin fund.',
#    'publishedAt': '2018-01-22T21:19:30Z',
#    'source': {'id': 'breitbart-news', 'name': 'Breitbart News'},
#    'title': 'Vanguard CEO: ‘You Will Never See a Fund from Vanguard on Bitcoin’',
#    'url': 'http://www.breitbart.com/tech/2018/01/22/vanguard-ceo-you-will-never-see-a-fund-from-vanguard-on-bitcoin/',
#    'urlToImage': 'http://media.breitbart.com/media/2018/01/wi/afp/22/35b668_nordea-nordic-region-biggest-bank-it-bar-employees-trading-in-bitcoin-cryptocurrencies-e1516655966314.jpg'},
#   {'author': 'Nate Church',
#    'description': "Founders' Fund has reportedly invested between 15 and 20 million dollars on the volatile cryptocurrency.",
#    'publishedAt': '2018-01-02T22:30:07Z',
#    'source': {'id': 'breitbart-news', 'name': 'Breitbart News'},
#    'title': 'Peter Thiel Betting Millions on Bitcoin',
# ...

# %%
sources = newsapi.get_sources(country='us')

# %%
sources
# Out:
# {'sources': [{'category': 'general',
#    'country': 'us',
#    'description': 'Your trusted source for breaking news, analysis, exclusive interviews, headlines, and videos at ABCNews.com.',
#    'id': 'abc-news',
#    'language': 'en',
#    'name': 'ABC News',
#    'url': 'http://abcnews.go.com'},
#   {'category': 'general',
#    'country': 'us',
#    'description': 'News, analysis from the Middle East and worldwide, multimedia and interactives, opinions, documentaries, podcasts, long reads and broadcast schedule.',
#    'id': 'al-jazeera-english',
#    'language': 'en',
#    'name': 'Al Jazeera English',
#    'url': 'http://www.aljazeera.com'},
#   {'category': 'technology',
#    'country': 'us',
#    'description': "The PC enthusiast's resource. Power users and the tools they love, without computing religion.",
#    'id': 'ars-technica',
#    'language': 'en',
#    'name': 'Ars Technica',
#    'url': 'http://arstechnica.com'},
#   {'category': 'general',
#    'country': 'us',
# ...
